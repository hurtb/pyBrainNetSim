# %% [markdown]
# ### Simple Display of The Internal Neural Network

# %%
# %matplotlib inline
import pyBrainNetSim.models.network as network
import pyBrainNetSim.generators.networks as nk
from pyBrainNetSim.drawing.viewers import draw_networkx

# %%
sm_prop_dist = nk.SensorMoverProperties()  # default set of distributions of the different variables in the mouse
net = network.NeuralNetData(sm_prop_dist.create_digraph())
ax = draw_networkx(net)
# Out:
# ---------------------------------------------------------------------------
# QhullError                                Traceback (most recent call last)
# <ipython-input-7-cdae6c5d5936> in <module>()
#       1 sm_prop_dist = nk.SensorMoverProperties()  # default set of distributions of the different variables in the mouse
#       2 net = network.NeuralNetData(sm_prop_dist.create_digraph())
# ----> 3 ax = draw_networkx(net)
#
# C:\code\pyBrainNetSim\pyBrainNetSim\drawing\viewers.pyc in draw_networkx(G, layout, ax, max_e, plot_active, active_node_color, **kwargs)
#      99     ax.add_patch(patches.Polygon(scale * np.array([all_points[k] for k in i_hull.vertices]), color=overall_color, alpha=overall_alpha))
#     100     i_points = np.array([p for p in nx.get_node_attributes(i_subg, 'pos').itervalues()])
# --> 101     i_hull = ConvexHull(i_points)
#     102     ax.add_patch(patches.Polygon(scale * np.array([i_points[k] for k in i_hull.vertices]), color=internal_color, alpha=internal_alpha))
#     103     firing_nc = colors.hex2color(active_node_color) if active_node_color is not None \
#
# scipy\spatial\qhull.pyx in scipy.spatial.qhull.ConvexHull.__init__ (scipy\spatial\qhull.c:21663)()
#
# scipy\spatial\qhull.pyx in scipy.spatial.qhull._Qhull.__init__ (scipy\spatial\qhull.c:3879)()
#
# QhullError: Qhull error

# %% [markdown]
# - **SIZE of the NEURONS**: proportional to the total strength of the post-synaptic neurons it synapses onto
# - **COLOR of the NEURONS**: Green represents excitatory neurons, and Red inhibitory. The shad of which is proportional to the amount of energy in the neuron.
# - **SHAPE of the NEURONS**: represents the type of neuron.
#   - Square = Sensory
#   - Hexagon = Motor
#   - Circle = Internal
# - **CONNECTIONS between NEURONS**: indicated by the black lines.
